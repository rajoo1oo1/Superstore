# %%
# !pip install pandas sqlalchemy==2.0.18
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 35.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.41
#     Uninstalling SQLAlchemy-2.0.41:
#       Successfully uninstalled SQLAlchemy-2.0.41
# ...

# %%
from sqlalchemy import create_engine

    # Create an engine that connects to a SQLite database file named 'mydatabase.db'
    # If the file doesn't exist, it will be created.
engine = create_engine('sqlite:///mydatabase.db')

# %%
df.to_sql('SampleSuperstore', engine, index=False, if_exists='replace')
# Out:
# 9994

# %%
sql_query='SELECT Segment,SUM(sales) as TotalSales from SampleSuperstore GROUP BY Segment ORDER BY SUM(Sales) DESC'
result_df=pd.read_sql_query(sql_query,engine)

# %%
result_df
# Out:
#        Segment    TotalSales
# 0     Consumer  1.161401e+06
# 1    Corporate  7.061464e+05
# 2  Home Office  4.296531e+05

# %%
sql_query='SELECT Region, AVG(Profit) as AverageProfit from SampleSuperstore GROUP BY Region ORDER BY AVG(Profit) DESC'
result_df=pd.read_sql_query(sql_query,engine)

# %%
result_df
# Out:
#     Region  AverageProfit
# 0     West      33.849032
# 1     East      32.135808
# 2    South      28.857673
# 3  Central      17.092709
